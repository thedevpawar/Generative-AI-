# %% [markdown]
# ### Experiment 3: Train the neural network on a benchmark dataset (e.g., MNIST, CIFAR-10) using backpropagation and a chosen optimization algorithm (e.g., stochastic gradient descent).

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

print(f"TensorFlow version: {tf.__version__}")
# Out:
# TensorFlow version: 2.19.0

# %% [markdown]
# #### 1. Load and Preprocess the MNIST Dataset
#
# The MNIST dataset consists of 70,000 grayscale images of handwritten digits (0-9), with 60,000 for training and 10,000 for testing. Each image is 28x28 pixels.

# %%
# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Normalize pixel values to be between 0 and 1
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Reshape images to (number of samples, height * width) for a dense layer
x_train = x_train.reshape(-1, 28 * 28)
x_test = x_test.reshape(-1, 28 * 28)

print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# x_train shape: (60000, 784)
# y_train shape: (60000,)
# x_test shape: (10000, 784)
# y_test shape: (10000,)

# %% [markdown]
# #### 2. Build the Neural Network Model

# %%
# Define the model architecture
model = keras.Sequential([
    keras.Input(shape=(28 * 28,)),
    layers.Dense(128, activation="relu", name="hidden_layer"),
    layers.Dense(10, activation="softmax", name="output_layer")
])

# Display the model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ hidden_layer (Dense)            │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### 3. Compile the Model
#
# We'll use `Stochastic Gradient Descent (SGD)` as the optimizer, `sparse_categorical_crossentropy` as the loss function (since our labels are integers 0-9), and `accuracy` as the metric.

# %%
# Compile the model
model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01), # SGD optimizer with a learning rate
    loss=keras.losses.SparseCategoricalCrossentropy(), # Loss function for integer labels
    metrics=["accuracy"], # Metric to monitor during training
)

# %% [markdown]
# #### 4. Train the Model

# %%
# Train the model
history = model.fit(
    x_train,
    y_train,
    batch_size=32,
    epochs=10,
    validation_split=0.1
)

print("\nTraining complete.")
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8295 - loss: 0.6877 - val_accuracy: 0.9170 - val_loss: 0.3187
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9028 - loss: 0.3487 - val_accuracy: 0.9307 - val_loss: 0.2581
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9162 - loss: 0.3000 - val_accuracy: 0.9368 - val_loss: 0.2328
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9238 - loss: 0.2701 - val_accuracy: 0.9417 - val_loss: 0.2111
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9304 - loss: 0.2473 - val_accuracy: 0.9458 - val_loss: 0.1942
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9357 - loss: 0.2287 - val_accuracy: 0.9522 - val_loss: 0.1829
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9400 - loss: 0.2125 - val_accuracy: 0.9568 - val_loss: 0.1694
# Epoch 8/10
# ...

# %% [markdown]
# #### 5. Evaluate the Model

# %%
# Evaluate the model on the test data
loss, accuracy = model.evaluate(x_test, y_test)

print(f"\nTest Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9513 - loss: 0.1681
#
# Test Loss: 0.1681
# Test Accuracy: 0.9513
